# %% [markdown]
# ### Create a stream of website visits records

# %%
from kafka import KafkaProducer
import datetime
import random
import json
import time

visits_topic="spark.streaming.website.visits"

def string_serializer(value):
    return value.encode('utf-8')
    
visits_producer=KafkaProducer( 
                bootstrap_servers=["localhost:9092"],
                key_serializer=string_serializer,
                value_serializer=string_serializer
                )

countries = ["USA","India","Brazil","Australia","Russia"]
last_actions = ["Catalog","FAQ","Order","ShoppingCart"]

#Generate 100 sample visit records
for i in range(1,100):

    #Create a json string with generated data
    json_record={}
    json_record["country"]=countries[random.randint(0,4)]
    json_record["last_action"]=last_actions[random.randint(0,3)]
    json_record["visit_date"]=datetime.datetime.today().strftime("%Y-%m-%d %H:%M:%S")
    json_record["duration"]=random.randint(1,20)

    #Use country as Key. Each country will go through the same partition, 
    #hence updates to a given country can be handled sequencially
    kafka_key=json_record["country"]
    kafka_value = json.dumps(json_record)
    print(kafka_value)
    visits_producer.send(visits_topic, key=kafka_key,value=kafka_value)

    #sleep for 1-3 seconds
    time.sleep(random.randint(1,3))

visits_producer.flush()
visits_producer.close()
# Out:
# {"country": "Australia", "last_action": "Order", "visit_date": "2024-08-12 13:01:16", "duration": 11}
# {"country": "Australia", "last_action": "Catalog", "visit_date": "2024-08-12 13:01:18", "duration": 16}
# {"country": "Australia", "last_action": "Order", "visit_date": "2024-08-12 13:01:20", "duration": 7}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2024-08-12 13:01:23", "duration": 7}
# {"country": "Russia", "last_action": "Order", "visit_date": "2024-08-12 13:01:24", "duration": 12}
# {"country": "India", "last_action": "FAQ", "visit_date": "2024-08-12 13:01:26", "duration": 15}
# {"country": "Australia", "last_action": "Catalog", "visit_date": "2024-08-12 13:01:27", "duration": 20}
# {"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:01:28", "duration": 9}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2024-08-12 13:01:29", "duration": 17}
# {"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:01:32", "duration": 14}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:01:35", "duration": 11}
# {"country": "India", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:01:37", "duration": 14}
# {"country": "Russia", "last_action": "Order", "visit_date": "2024-08-12 13:01:39", "duration": 8}
# {"country": "India", "last_action": "Catalog", "visit_date": "2024-08-12 13:01:41", "duration": 5}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2024-08-12 13:01:44", "duration": 9}
# {"country": "Brazil", "last_action": "FAQ", "visit_date": "2024-08-12 13:01:47", "duration": 19}
# {"country": "Australia", "last_action": "Order", "visit_date": "2024-08-12 13:01:49", "duration": 15}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2024-08-12 13:01:52", "duration": 12}
# {"country": "Australia", "last_action": "FAQ", "visit_date": "2024-08-12 13:01:53", "duration": 2}
# {"country": "Russia", "last_action": "Catalog", "visit_date": "2024-08-12 13:01:56", "duration": 13}
# {"country": "USA", "last_action": "FAQ", "visit_date": "2024-08-12 13:01:57", "duration": 13}
# {"country": "Australia", "last_action": "Catalog", "visit_date": "2024-08-12 13:01:59", "duration": 3}
# {"country": "Brazil", "last_action": "FAQ", "visit_date": "2024-08-12 13:02:00", "duration": 15}
# {"country": "USA", "last_action": "Order", "visit_date": "2024-08-12 13:02:02", "duration": 17}
# {"country": "Russia", "last_action": "Catalog", "visit_date": "2024-08-12 13:02:04", "duration": 2}
# {"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:02:06", "duration": 4}
# {"country": "Brazil", "last_action": "FAQ", "visit_date": "2024-08-12 13:02:09", "duration": 17}
# {"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:02:12", "duration": 16}
# {"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:02:13", "duration": 10}
# {"country": "India", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:02:15", "duration": 13}
# {"country": "India", "last_action": "Order", "visit_date": "2024-08-12 13:02:16", "duration": 2}
# {"country": "USA", "last_action": "FAQ", "visit_date": "2024-08-12 13:02:18", "duration": 1}
# {"country": "USA", "last_action": "Order", "visit_date": "2024-08-12 13:02:19", "duration": 17}
# {"country": "India", "last_action": "Catalog", "visit_date": "2024-08-12 13:02:20", "duration": 9}
# {"country": "Brazil", "last_action": "Catalog", "visit_date": "2024-08-12 13:02:21", "duration": 3}
# {"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:02:22", "duration": 11}
# {"country": "India", "last_action": "FAQ", "visit_date": "2024-08-12 13:02:25", "duration": 2}
# {"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:02:26", "duration": 4}
# {"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:02:27", "duration": 3}
# {"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:02:28", "duration": 11}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2024-08-12 13:02:29", "duration": 4}
# {"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:02:31", "duration": 5}
# {"country": "India", "last_action": "Catalog", "visit_date": "2024-08-12 13:02:32", "duration": 17}
# {"country": "Russia", "last_action": "Order", "visit_date": "2024-08-12 13:02:35", "duration": 5}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2024-08-12 13:02:38", "duration": 15}
# {"country": "Brazil", "last_action": "FAQ", "visit_date": "2024-08-12 13:02:41", "duration": 16}
# {"country": "Russia", "last_action": "Order", "visit_date": "2024-08-12 13:02:42", "duration": 5}
# {"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:02:44", "duration": 20}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2024-08-12 13:02:46", "duration": 11}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2024-08-12 13:02:47", "duration": 6}
# {"country": "Brazil", "last_action": "Catalog", "visit_date": "2024-08-12 13:02:49", "duration": 15}
# {"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:02:50", "duration": 20}
# {"country": "Australia", "last_action": "Order", "visit_date": "2024-08-12 13:02:51", "duration": 11}
# {"country": "Russia", "last_action": "Order", "visit_date": "2024-08-12 13:02:54", "duration": 14}
# {"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2024-08-12 13:02:55", "duration": 12}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 39
#      36     visits_producer.send(visits_topic, key=kafka_key,value=kafka_value)
#      38     #sleep for 1-3 seconds
# ---> 39     time.sleep(random.randint(1,3))
#      41 visits_producer.flush()
#      42 visits_producer.close()
#
# KeyboardInterrupt:

# %%
#Consumer test - to test if topic data is published correctly
from kafka import KafkaConsumer

def string_deserializer(value):
    return value.decode('utf-8')
    
visits_consumer=KafkaConsumer(
                bootstrap_servers=["localhost:9092"],
                value_deserializer=string_deserializer,
                auto_offset_reset="latest"
                )

visits_consumer.subscribe(visits_topic)

messages = visits_consumer.poll()
print("Total messages :", len(messages))
for message in messages:
    print("%d:%d: vs=%s" % (message.partition, message.offset, message.value))
