# %%
inp = [[[[[[[[[['njT', 22.601153, 34, 'qxJAE'], ['ErC', 54.089845, 47, 'MYqWe']],
         [['YgA', 32.707177, 48, '/piZT'], ['xxc', 69.677439, 75, 'NFh?:']]],
        [[['kLQ', 94.339361, 27, 'iDvp}'], ['dyr', 21.603911, 36, '}c>-K']],
         [['mQT', 22.163991, 78, '-Mq,p'], ['FIE', 51.572103, 54, 'R!VUh']]]],
       [[[['mJs', 87.806774, 99, 'P|]jG'], ['DEb', 83.741715, 93, '!I%;r']],
         [['qgx', 47.653515, 90, '?yf_T'], ['WVB', 28.481847, 96, '`U<Hm']]],
        [[['SuK', 53.456289, 29, 'pB]af'], ['hmq', 15.494708, 10, '"eXU^']],
         [['ZsC', 42.676398, 20, 'PG%n*'], ['MJU', 40.487616, 33, '$uB-t']]]]]]]]]]
         
print(inp)
# Out:
# [[[[[[[[[['njT', 22.601153, 34, 'qxJAE'], ['ErC', 54.089845, 47, 'MYqWe']], [['YgA', 32.707177, 48, '/piZT'], ['xxc', 69.677439, 75, 'NFh?:']]], [[['kLQ', 94.339361, 27, 'iDvp}'], ['dyr', 21.603911, 36, '}c>-K']], [['mQT', 22.163991, 78, '-Mq,p'], ['FIE', 51.572103, 54, 'R!VUh']]]], [[[['mJs', 87.806774, 99, 'P|]jG'], ['DEb', 83.741715, 93, '!I%;r']], [['qgx', 47.653515, 90, '?yf_T'], ['WVB', 28.481847, 96, '`U<Hm']]], [[['SuK', 53.456289, 29, 'pB]af'], ['hmq', 15.494708, 10, '"eXU^']], [['ZsC', 42.676398, 20, 'PG%n*'], ['MJU', 40.487616, 33, '$uB-t']]]]]]]]]]

# %%
res = []
def flat(inp):
    for i in inp:
        if type(i) is list:
            flat(i)
        else:
            res.append(i)

flat(inp)
print(res)
# Out:
# ['njT', 22.601153, 34, 'qxJAE', 'ErC', 54.089845, 47, 'MYqWe', 'YgA', 32.707177, 48, '/piZT', 'xxc', 69.677439, 75, 'NFh?:', 'kLQ', 94.339361, 27, 'iDvp}', 'dyr', 21.603911, 36, '}c>-K', 'mQT', 22.163991, 78, '-Mq,p', 'FIE', 51.572103, 54, 'R!VUh', 'mJs', 87.806774, 99, 'P|]jG', 'DEb', 83.741715, 93, '!I%;r', 'qgx', 47.653515, 90, '?yf_T', 'WVB', 28.481847, 96, '`U<Hm', 'SuK', 53.456289, 29, 'pB]af', 'hmq', 15.494708, 10, '"eXU^', 'ZsC', 42.676398, 20, 'PG%n*', 'MJU', 40.487616, 33, '$uB-t']

# %%
def my_custom_sort(item):
    if isinstance(item, str) and item.isalnum():
        return (1, item)
    if isinstance(item, str):
        return (0, item)
    if isinstance(item, int):
        return (2, item)
    if isinstance(item, float):
        return (3, item)


sorted_res = sorted(res, key=my_custom_sort)



for i in range(0,len(sorted_res)):
    print(sorted_res[i:i+15])
# Out:
# ['!I%;r', '"eXU^', '$uB-t', '-Mq,p', '/piZT', '?yf_T', 'NFh?:', 'PG%n*', 'P|]jG', 'R!VUh', '`U<Hm', 'iDvp}', 'pB]af', '}c>-K', 'DEb']
# ['"eXU^', '$uB-t', '-Mq,p', '/piZT', '?yf_T', 'NFh?:', 'PG%n*', 'P|]jG', 'R!VUh', '`U<Hm', 'iDvp}', 'pB]af', '}c>-K', 'DEb', 'ErC']
# ['$uB-t', '-Mq,p', '/piZT', '?yf_T', 'NFh?:', 'PG%n*', 'P|]jG', 'R!VUh', '`U<Hm', 'iDvp}', 'pB]af', '}c>-K', 'DEb', 'ErC', 'FIE']
# ['-Mq,p', '/piZT', '?yf_T', 'NFh?:', 'PG%n*', 'P|]jG', 'R!VUh', '`U<Hm', 'iDvp}', 'pB]af', '}c>-K', 'DEb', 'ErC', 'FIE', 'MJU']
# ['/piZT', '?yf_T', 'NFh?:', 'PG%n*', 'P|]jG', 'R!VUh', '`U<Hm', 'iDvp}', 'pB]af', '}c>-K', 'DEb', 'ErC', 'FIE', 'MJU', 'MYqWe']
# ['?yf_T', 'NFh?:', 'PG%n*', 'P|]jG', 'R!VUh', '`U<Hm', 'iDvp}', 'pB]af', '}c>-K', 'DEb', 'ErC', 'FIE', 'MJU', 'MYqWe', 'SuK']
# ['NFh?:', 'PG%n*', 'P|]jG', 'R!VUh', '`U<Hm', 'iDvp}', 'pB]af', '}c>-K', 'DEb', 'ErC', 'FIE', 'MJU', 'MYqWe', 'SuK', 'WVB']
# ...

# %%
for i in range(0,len(res)):
    print(res[i:i+15])
# Out:
# ['njT', 22.601153, 34, 'qxJAE', 'ErC', 54.089845, 47, 'MYqWe', 'YgA', 32.707177, 48, '/piZT', 'xxc', 69.677439, 75]
# [22.601153, 34, 'qxJAE', 'ErC', 54.089845, 47, 'MYqWe', 'YgA', 32.707177, 48, '/piZT', 'xxc', 69.677439, 75, 'NFh?:']
# [34, 'qxJAE', 'ErC', 54.089845, 47, 'MYqWe', 'YgA', 32.707177, 48, '/piZT', 'xxc', 69.677439, 75, 'NFh?:', 'kLQ']
# ['qxJAE', 'ErC', 54.089845, 47, 'MYqWe', 'YgA', 32.707177, 48, '/piZT', 'xxc', 69.677439, 75, 'NFh?:', 'kLQ', 94.339361]
# ['ErC', 54.089845, 47, 'MYqWe', 'YgA', 32.707177, 48, '/piZT', 'xxc', 69.677439, 75, 'NFh?:', 'kLQ', 94.339361, 27]
# [54.089845, 47, 'MYqWe', 'YgA', 32.707177, 48, '/piZT', 'xxc', 69.677439, 75, 'NFh?:', 'kLQ', 94.339361, 27, 'iDvp}']
# [47, 'MYqWe', 'YgA', 32.707177, 48, '/piZT', 'xxc', 69.677439, 75, 'NFh?:', 'kLQ', 94.339361, 27, 'iDvp}', 'dyr']
# ['MYqWe', 'YgA', 32.707177, 48, '/piZT', 'xxc', 69.677439, 75, 'NFh?:', 'kLQ', 94.339361, 27, 'iDvp}', 'dyr', 21.603911]
# ...
