# %%
#Consumer test
from kafka import KafkaConsumer
import redis
import time
import mariadb

def string_deserializer(value):
    return value.decode('utf-8')

#Setup Kafka
visits_topic="spark.streaming.carts.abandoned"
    
visits_consumer=KafkaConsumer(
                bootstrap_servers=["localhost:9092"],
                group_id=None,
                value_deserializer=string_deserializer,
                auto_offset_reset="latest"
                )

visits_consumer.subscribe(visits_topic)

#Setup redis
redis_conn=redis.Redis(host="localhost", port=6379, decode_responses=True)

#setup mariadb conn
summary_conn = mariadb.connect(
                user="spark",
                password="spark",
                host="127.0.0.1",
                port=3306,
                database="website_stats",
                autocommit=True
            )
summary_cursor = summary_conn.cursor()
    
summary_stats_sql=f"""
            SELECT last_action, SUM(duration) as duration
            FROM `website_stats`.`visit_stats` 
            GROUP BY last_action
            """

while(True):

    print("\n**************************************************")
    #Fetch Kafka messages
    messages = visits_consumer.poll()
    print("Shopping Cart from Kafka\n-------------------------")
    for partition,records in messages.items():
        for record in records:
            print(record.value)

    #Print country stats from Redis
    print("\nCountry Stats from Redis\n-------------------------")
    scores=redis_conn.zrevrangebyscore("last-action-stats",99999,0,withscores=True)
    for score in scores:
        print(score[0], " = ", score[1])

    #Print summary stats for last action
    print("\nLast Action stats from mariaDB\n----------------------")
    summary_cursor.execute(summary_stats_sql)
    for last_action, duration in summary_cursor:
        print(last_action, " = ", duration)

    time.sleep(5)
# Out:
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# Australia  =  33.0
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# Australia  =  102.0
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# Australia  =  102.0
# India  =  45.0
# Russia  =  36.0
# Brazil  =  21.0
#
# Last Action stats from mariaDB
# ----------------------
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# Australia  =  162.0
# Russia  =  87.0
# Brazil  =  76.0
# India  =  45.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  48
# Order  =  33
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# Australia  =  162.0
# Brazil  =  90.0
# Russia  =  87.0
# India  =  73.0
# USA  =  33.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  68
# FAQ  =  32
# Order  =  87
# ShoppingCart  =  9
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
# Brazil,ShoppingCart,1723467688000000,9
# Brazil,ShoppingCart,1723467692000000,14
# USA,ShoppingCart,1723467695000000,11
#
# Country Stats from Redis
# -------------------------
# Australia  =  162.0
# Russia  =  111.0
# India  =  102.0
# Brazil  =  90.0
# USA  =  33.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  108
# FAQ  =  96
# Order  =  111
# ShoppingCart  =  27
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# Australia  =  162.0
# Russia  =  138.0
# Brazil  =  128.0
# India  =  102.0
# USA  =  33.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  108
# FAQ  =  96
# Order  =  111
# ShoppingCart  =  69
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
# India,ShoppingCart,1723467697000000,14
#
# Country Stats from Redis
# -------------------------
# Australia  =  207.0
# Brazil  =  171.0
# Russia  =  138.0
# India  =  102.0
# USA  =  33.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  108
# FAQ  =  96
# Order  =  135
# ShoppingCart  =  144
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# Australia  =  213.0
# Brazil  =  183.0
# Russia  =  177.0
# India  =  102.0
# USA  =  33.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  123
# FAQ  =  123
# Order  =  135
# ShoppingCart  =  144
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# Brazil  =  228.0
# Australia  =  222.0
# Russia  =  177.0
# India  =  102.0
# USA  =  89.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  123
# FAQ  =  180
# Order  =  180
# ShoppingCart  =  144
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# Brazil  =  240.0
# Australia  =  222.0
# Russia  =  183.0
# USA  =  123.0
# India  =  102.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  123
# FAQ  =  186
# Order  =  216
# ShoppingCart  =  144
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
# Brazil,ShoppingCart,1723467726000000,4
#
# Country Stats from Redis
# -------------------------
# Brazil  =  291.0
# Australia  =  222.0
# Russia  =  215.0
# USA  =  123.0
# India  =  102.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  171
# FAQ  =  225
# Order  =  216
# ShoppingCart  =  144
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# Brazil  =  321.0
# Russia  =  231.0
# Australia  =  222.0
# India  =  147.0
# USA  =  123.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  177
# FAQ  =  270
# Order  =  267
# ShoppingCart  =  144
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
# Russia,ShoppingCart,1723467732000000,16
# Brazil,ShoppingCart,1723467733000000,10
# India,ShoppingCart,1723467735000000,13
#
# Country Stats from Redis
# -------------------------
# Brazil  =  330.0
# Russia  =  242.0
# Australia  =  222.0
# USA  =  177.0
# India  =  174.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  177
# FAQ  =  321
# Order  =  267
# ShoppingCart  =  234
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
#
# Country Stats from Redis
# -------------------------
# Brazil  =  330.0
# Russia  =  279.0
# Australia  =  222.0
# India  =  180.0
# USA  =  177.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  177
# FAQ  =  321
# Order  =  267
# ShoppingCart  =  234
#
# **************************************************
# Shopping Cart from Kafka
# -------------------------
# Russia,ShoppingCart,1723467742000000,11
# Russia,ShoppingCart,1723467746000000,4
#
# Country Stats from Redis
# -------------------------
# Brazil  =  378.0
# Russia  =  285.0
# Australia  =  222.0
# USA  =  189.0
# India  =  180.0
#
# Last Action stats from mariaDB
# ----------------------
# Catalog  =  189
# FAQ  =  324
# Order  =  290
# ShoppingCart  =  284
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 64
#      61 for last_action, duration in summary_cursor:
#      62     print(last_action, " = ", duration)
# ---> 64 time.sleep(5)
#
# KeyboardInterrupt:
